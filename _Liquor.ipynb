# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
liquor = pd.read_csv("Iowa_Liquor_Sales\Iowa_Liquor_Sales.csv")
liquor.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-46058900046  03/30/2022          2675
# 1     INV-20243000035  06/26/2019          2522
# 2     INV-19929800031  06/11/2019          2660
# 3     INV-19863100014  06/07/2019          3065
# 4     INV-20285700172  06/28/2019          5236
#
#                               Store Name            Address          City  \
# 0                 Hy-Vee #2 / Coralville  3285 Crosspark Rd    Coralville
# 1  Hy-Vee Wine and Spirits / Spirit Lake         Hwy 9 & 71   Spirit Lake
# 2       HY-VEE FOOD STORE / SIOUX CENTER    1951 S Main Ave  Sioux Center
# 3                   Montezuma Super Valu     201 S Front St     Montezuma
# 4       Giggle Juice Liquor Station, LLC      600 W Main St       Anamosa
#
#    Zip Code                        Store Location  County Number     County  \
# 0   52241.0          POINT (-91.605881 41.722419)           52.0    JOHNSON
# 1   51360.0                                   NaN           30.0  DICKINSON
# 2   51250.0          POINT (-96.175695 43.056471)           84.0      SIOUX
# 3   50171.0          POINT (-92.527248 41.584179)           79.0  POWESHIEK
# 4   52205.0  POINT (-91.29083400000002 42.108203)           53.0      JONES
#
#    ...  Item Number             Item Description  Pack Bottle Volume (ml)  \
# 0  ...        80239  Iowish Cream Salted Caramel     6                750
# 1  ...        37356               Phillips Vodka    12                750
# 2  ...        38008           Smirnoff 80prf PET     6               1750
# 3  ...        36976                Nikolai Vodka    12                750
# 4  ...        35916           Five O'Clock Vodka    12                750
#
#    State Bottle Cost State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0              10.17               15.26             6           91.56
# 1               3.57                5.36            12           64.32
# 2              14.75               22.13             6          132.78
# 3               3.27                4.91             3           14.73
# 4               3.37                5.06             3           15.18
#
#    Volume Sold (Liters)  Volume Sold (Gallons)
# 0                  4.50                   1.18
# 1                  9.00                   2.37
# 2                 10.50                   2.77
# 3                  2.25                   0.59
# 4                  2.25                   0.59
#
# [5 rows x 24 columns]

# %%
print("Liquor Data Size: ", liquor.size)
print("Liquor Data Shape: ", liquor.shape)
# Out:
# Liquor Data Size:  184550712
# Liquor Data Shape:  (7689613, 24)

# %%
liquor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7689613 entries, 0 to 7689612
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               float64
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               float64
#  11  Category Name          object
#  12  Vendor Number          float64
#  13  Vendor Name            object
#  14  Item Number            int64
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      float64
#  19  State Bottle Retail    float64
#  20  Bottles Sold           int64
#  21  Sale (Dollars)         float64
#  22  Volume Sold (Liters)   float64
#  23  Volume Sold (Gallons)  float64
# dtypes: float64(9), int64(5), object(10)
# memory usage: 1.4+ GB
